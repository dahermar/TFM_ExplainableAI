# %% [markdown]
# # Regresores. Estudio de outliers

# %% [markdown]
# En este notebook se realizará un estudio de los outliers del conjunto completo de datos.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from explainerdashboard import RegressionExplainer, ClassifierExplainer, ExplainerDashboard
from math import sqrt

RANDOM_STATE = 123

# %% [markdown]
# Cargamos los datos y eliminamos las columnas con gran cantidad de nulos, fechas, descripción en lenguaje natural y repetidas en ambos datasets. También eliminamos las columnas con gran cantidad de valores, ya que analizando los resultados del notebook anterior, decidí continuar sin esas columnas

# %%
smt_2020_df = pd.read_excel('data/I11_SMT Incidents 2020.xlsx')

smt_2020_df.columns = smt_2020_df.iloc[11].values
smt_2020_df = smt_2020_df.iloc[12:]
smt_2020_df = smt_2020_df.reset_index(drop=True)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default

# %%
smt_2021_df = pd.read_excel('data/I11_SMT Incidents 2021.xlsx')

smt_2021_df.columns = smt_2021_df.iloc[11].values
smt_2021_df = smt_2021_df.iloc[12:]
smt_2021_df = smt_2021_df.reset_index(drop=True)

# %%
smt_2022_df = pd.read_excel('data/I11_SMT Incidents 2022.xlsx')

smt_2022_df.columns = smt_2022_df.iloc[11].values
smt_2022_df = smt_2022_df.iloc[12:]
smt_2022_df = smt_2022_df.reset_index(drop=True)

# %%
smt_df = pd.concat([smt_2020_df, smt_2021_df, smt_2022_df])
smt_df.reset_index(drop=True,inplace=True)

pd.set_option('display.max_columns', None)

smt_df
# Out:
#            Incident ID Original Incident Number Requisition ID  \
# 0      INC000017348507                      NaN            NaN
# 1      INC000017354421                      NaN            NaN
# 2      INC000017400389                      NaN            NaN
# 3      INC000017470045                      NaN       10065659
# 4      INC000017470799                      NaN       10061208
# ...                ...                      ...            ...
# 11944  INC000023672229                      NaN            NaN
# 11945  INC000023674299                      NaN            NaN
# 11946  INC000023674336                      NaN            NaN
# 11947  INC000023678629                      NaN            NaN
# 11948  INC000023681413                      NaN            NaN
#
#       Created Date (UTC+0)        Open Incident Type  \
# 0         02.01.2020 11:00              Not assigned
# 1         04.01.2020 17:52              Not assigned
# 2         13.01.2020 09:51              Not assigned
# 3         23.01.2020 14:49              Not assigned
# 4         23.01.2020 16:51              Not assigned
# ...                    ...                       ...
# 11944     27.12.2022 15:02  User Service Restoration
# 11945     28.12.2022 12:22  User Service Restoration
# 11946     28.12.2022 09:17      User Service Request
# 11947     29.12.2022 12:21      User Service Request
# 11948     30.12.2022 11:46      User Service Request
#
#           Current Incident Type  Status                Status Reason Company  \
# 0          User Service Request  Closed   No Further Action Required      AE
# 1          User Service Request  Closed   No Further Action Required      AE
# 2          User Service Request  Closed  Customer Follow-Up Required      AE
# 3          User Service Request  Closed   No Further Action Required       M
# 4          User Service Request  Closed   No Further Action Required      TT
# ...                         ...     ...                          ...     ...
# 11944  User Service Restoration  Closed   No Further Action Required       C
# 11945  User Service Restoration  Closed   No Further Action Required      GS
# 11946      User Service Request  Closed   No Further Action Required      AE
# 11947      User Service Request  Closed   No Further Action Required      AE
# 11948      User Service Request  Closed   No Further Action Required      SO
#
#       Customer Department Region Site Group Site Desk Location  \
# 0             RBEM/MSS4-Q   EMEA         ES  MD1     MD1 150P3
# 1             RBEM/MSS4-Q   EMEA         ES  MD1     Md1 150P3
# 2               RBEM/LOP1   EMEA         ES  MD1     Md1 155P3
# 3             M/PQA1-RBEM   EMEA         ES  MD1     Md1 162P4
# 4              TT/SSP-ASA   EMEA         ES   MD            Md
# ...                   ...    ...        ...  ...           ...
# 11944              MED-ES   EMEA         ES   MD        MED-ES
# 11945     GS/OBR221-EMEA2   EMEA         ES   MD            Md
# 11946          RBEM/TEF10   EMEA         ES  MD1     Md1 155P4
# 11947            RBEM/LOW   EMEA         ES  MD1           Md1
# 11948         SO/ISC11-ES   EMEA         ES  ALD           Ald
#
#       Reported Source                                      Summary  \
# 0               Phone         Ampliar fecha de validez de windows#
# 1               Phone                       Cuenta de NT caducada#
# 2               Email                            usuario caducado#
# 3             Walk In  My Mobile  MSD Micro Pilot : Order Service#
# 4               Other  My Mobile  MSD Micro Pilot : Order Service#
# ...               ...                                          ...
# 11944           Phone                         wmedtra not working#
# 11945           Phone                                Mobile phone#
# 11946         Walk In                              Reset password#
# 11947           Phone                   Ampliacion cuenta windows#
# 11948    Direct Input   AA Hotline - Access CRM from RBIB network#
#
#                   Impact Open Priority Current Priority Assigned Group  \
# 0      4-Minor/Localized        Medium           Medium   Iberia4 -Md-
# 1      4-Minor/Localized           Low           Medium   Iberia4 -Md-
# 2      4-Minor/Localized           Low           Medium   Iberia4 -Md-
# 3      4-Minor/Localized           Low              Low   Iberia4 -Md-
# 4      4-Minor/Localized           Low              Low   Iberia4 -Md-
# ...                  ...           ...              ...            ...
# 11944  4-Minor/Localized           Low              Low         Spain1
# 11945  4-Minor/Localized           Low              Low         Spain1
# 11946  4-Minor/Localized           Low              Low         Spain1
# 11947  4-Minor/Localized           Low              Low         Spain1
# 11948  4-Minor/Localized        Medium           Medium         Spain1
#
#       Assigned Group Department In Progess Time (hhh:mi)\n  \
# 0                     CI/CER-IB                Not Defined
# 1                     CI/CER-IB                Not Defined
# 2                     CI/CER-IB                        0:4
# 3                     CI/CER-IB                      170:8
# 4                     CI/CER-IB                     360:45
# ...                         ...                        ...
# 11944                 BD/PFE-IA                Not Defined
# 11945                 BD/PFE-IA                Not Defined
# 11946                 BD/PFE-IA                Not Defined
# 11947                 BD/PFE-IA                Not Defined
# 11948                 BD/PFE-IA                       4:21
#
#       Actual Duration/Open Time (hhh:mi)  \
# 0                                0260:05
# 1                                0205:20
# 2                                0022:02
# 3                                0502:49
# 4                                0475:00
# ...                                  ...
# 11944                            0023:56
# 11945                            0000:35
# 11946                            0000:01
# 11947                            0000:16
# 11948                            0073:00
#
#       Down Time of CI-Unavailability (hhh:mi) Last Modified Date (UTC+0)  \
# 0                               Not Specified           31.03.2020 22:04
# 1                               Not Specified           31.03.2020 22:04
# 2                               Not Specified           31.03.2020 22:04
# 3                               Not Specified           19.03.2020 22:00
# 4                               Not Specified           18.03.2020 22:00
# ...                                       ...                        ...
# 11944                           Not Specified           01.02.2023 22:00
# 11945                           Not Specified           01.02.2023 22:00
# 11946                           Not Specified           01.02.2023 22:00
# 11947                           Not Specified           02.02.2023 22:00
# 11948                           Not Specified           25.03.2023 04:57
#
#       First Resolved Date (UTC+0) Last Resolved Date (UTC+0) Created Month  \
# 0                03.01.2020 07:21           13.01.2020 07:05      JAN 2020
# 1                05.01.2020 11:48           13.01.2020 07:12      JAN 2020
# 2                13.01.2020 10:39           14.01.2020 07:53      JAN 2020
# 3                13.02.2020 13:38           13.02.2020 13:38      JAN 2020
# 4                12.02.2020 11:51           12.02.2020 11:51      JAN 2020
# ...                           ...                        ...           ...
# 11944            28.12.2022 14:58           28.12.2022 14:58      DEC 2022
# 11945            28.12.2022 12:57           28.12.2022 12:57      DEC 2022
# 11946            28.12.2022 09:18           28.12.2022 09:18      DEC 2022
# 11947            29.12.2022 12:37           29.12.2022 12:37      DEC 2022
# 11948            02.01.2023 12:46           02.01.2023 12:46      DEC 2022
#
#       Operational Categorization Tier 1 Operational Categorization Tier 2  \
# 0                               Request                          - None -
# 1                               Request                            Modify
# 2                               Request                          - None -
# 3                               Request                          - None -
# 4                               Request                          - None -
# ...                                 ...                               ...
# 11944                           Failure                       Application
# 11945                           Failure                          - None -
# 11946                           Request                          - None -
# 11947                           Request                          - None -
# 11948                           Request                          - None -
#
#       Operational Categorization Tier 3                            Service+  \
# 0                              - None -      CI-CAT ADMINISTRATION |IBERIA4
# 1                              - None -             NT USER MODIFY |IBERIA4
# 2                              - None -      CI-CAT ADMINISTRATION |IBERIA4
# 3                              - None -  MY MOBILE - LOCAL SUPPORT |IBERIA4
# 4                              - None -  MY MOBILE - LOCAL SUPPORT |IBERIA4
# ...                                 ...                                 ...
# 11944                          - None -            SOFTWARE NO SCCM |SPAIN1
# 11945                          - None -     TELEPHONY LOCAL SUPPORT |SPAIN1
# 11946                          - None -         NT PASSWORD RESET |EMEA, LA
# 11947                          - None -       CI-CAT ADMINISTRATION |SPAIN1
# 11948                          - None -            SOFTWARE NO SCCM |SPAIN1
#
#                                    CI+ Product Categorization Tier 1  \
# 0                                  NaN                       Service
# 1                                  NaN                       Service
# 2                                  NaN                       Service
# 3                                  NaN                       Service
# 4                                  NaN                       Service
# ...                                ...                           ...
# 11944         SOFTWARE NO SCCM |SPAIN1                       Service
# 11945  TELEPHONY LOCAL SUPPORT |SPAIN1                       Service
# 11946      NT PASSWORD RESET |EMEA, LA                       Service
# 11947                              NaN                       Service
# 11948                              NaN                       Service
#
#       Product Categorization Tier 2 Product Categorization Tier 3  \
# 0            Infrastructure Service               Support Service
# 1            Infrastructure Service               Support Service
# 2            Infrastructure Service               Support Service
# 3                End Device Service         Mobile Device Service
# 4                End Device Service         Mobile Device Service
# ...                             ...                           ...
# 11944           Application Service           Application Service
# 11945                    IT Service                    IT Service
# 11946                    IT Service                    IT Service
# 11947        Infrastructure Service               Support Service
# 11948           Application Service           Application Service
#
#       Product Name Resolution Categorization Tier 1  \
# 0              NaN                          Request
# 1              NaN                          Request
# 2              NaN                          Request
# 3              NaN                          Request
# 4              NaN                          Request
# ...            ...                              ...
# 11944          NaN                         Handling
# 11945          NaN                         Handling
# 11946          NaN                          Request
# 11947          NaN                          Request
# 11948          NaN                          Request
#
#       Resolution Categorization Tier 2 Resolution Categorization Tier 3  \
# 0                          User Rights                         - None -
# 1                          User Rights                         - None -
# 2                             - None -                         - None -
# 3                             - None -                         - None -
# 4                             - None -                         - None -
# ...                                ...                              ...
# 11944                          Unclear                         - None -
# 11945                          Unclear                         - None -
# 11946                         - None -                         - None -
# 11947                      User Rights                         - None -
# 11948                         - None -                         - None -
#
#       Resolution Product Categorization Tier 1  \
# 0                                      Service
# 1                                      Service
# 2                                      Service
# 3                                      Service
# 4                                      Service
# ...                                        ...
# 11944                                  Service
# 11945                                  Service
# 11946                                  Service
# 11947                                  Service
# 11948                                  Service
#
#       Resolution Product Categorization Tier 2  \
# 0                       Infrastructure Service
# 1                       Infrastructure Service
# 2                       Infrastructure Service
# 3                           End Device Service
# 4                           End Device Service
# ...                                        ...
# 11944                      Application Service
# 11945                               IT Service
# 11946                               IT Service
# 11947                   Infrastructure Service
# 11948                      Application Service
#
#       Resolution Product Categorization Tier 3 Resolution Product Name  \
# 0                              Support Service                     NaN
# 1                              Support Service                     NaN
# 2                              Support Service                     NaN
# 3                        Mobile Device Service                     NaN
# 4                        Mobile Device Service                     NaN
# ...                                        ...                     ...
# 11944                      Application Service                     NaN
# 11945                               IT Service                     NaN
# 11946                               IT Service                     NaN
# 11947                          Support Service                     NaN
# 11948                      Application Service                     NaN
#
#       Primary Center Code Target Date  \
# 0                  965899
# 1                  965859
# 2                  965138
# 3                     NaN
# 4                     NaN
# ...                   ...         ...
# 11944              933206
# 11945              933335
# 11946              965313
# 11947              965107
# 11948                5517
#
#                                                    Notes  \
# 0      I: Important: I: Do NOT use this service for r...
# 1      30.06.2020  Q: User ID (e.g. xyz8fe): A: GSS2M...
# 2      Su solicitud vía e-mail ha sido transferida a ...
# 3      ------------------------------------------ // ...
# 4      ------------------------------------------ // ...
# ...                                                  ...
# 11944  Q: User ID (e.g. xyz8fe): A:ROO2MD  Q: Compute...
# 11945  Q: User ID (e.g. xyz8fe): A: SSS1MD    Q: Comp...
# 11946                                 Request - IT Space
# 11947  I: Important: I: Do NOT use this service for r...
# 11948  Dear Team  We need you to execute a command: i...
#
#                                               Resolution Created by CI-Hotline
# 0      Se habilita la cuenta NT, esta se desactivo ce...                   Yes
# 1      Se amplía de nuevo la fecha de validez del usu...                   Yes
# 2      Como ya dijimos al cerrar el ticket, la valide...                   Yes
# 3                 Móvil MD-Y1733 entregado y configurado                   Yes
# 4                   Dispositivo configurado y entregado.                   Yes
# ...                                                  ...                   ...
# 11944  El usuario nos informa que el problema ya esta...                   Yes
# 11945  Tras contactar con la usuaria, se comprueba de...                   Yes
# 11946  Dear customer,   Por favor evalúe el servicio ...                    No
# 11947  Se amplia fecha de validez.  Atentamente Md IT...                   Yes
# 11948  El rango de IP's que hay que habilitar es el s...                    No
#
# [11949 rows x 49 columns]

# %%
celonis_2020_df = pd.read_excel('data/Tickets_Celonis_2020.xlsx')
celonis_2020_df = celonis_2020_df.reset_index(drop=True)

# %%
celonis_2021_df = pd.read_excel('data/Tickets_Celonis_2021.xlsx')
celonis_2021_df = celonis_2021_df.reset_index(drop=True)

# %%
celonis_2022_df = pd.read_excel('data/Tickets_Celonis_2022.xlsx')
celonis_2022_df = celonis_2022_df.reset_index(drop=True)

# %%
celonis_df = pd.concat([celonis_2020_df, celonis_2021_df, celonis_2022_df])
celonis_df.reset_index(drop=True,inplace=True)

celonis_df
# Out:
#        Incident Number         Submit Date                     Service Name  \
# 0      INC000017346024 2020-01-02 05:46:38   CI-CAT ADMINISTRATION |IBERIA4
# 1      INC000017346091 2020-01-02 06:42:34   CI-CAT ADMINISTRATION |IBERIA4
# 2      INC000017346702 2020-01-02 06:57:03   CI-CAT ADMINISTRATION |IBERIA4
# 3      INC000017346738 2020-01-02 07:31:46   CI-CAT ADMINISTRATION |IBERIA4
# 4      INC000017346753 2020-01-02 07:55:23   CI-CAT ADMINISTRATION |IBERIA4
# ...                ...                 ...                              ...
# 14733  INC000023672067 2022-12-27 15:59:26    CI-CAT ADMINISTRATION |SPAIN1
# 14734  INC000023672229 2022-12-27 15:06:34         SOFTWARE NO SCCM |SPAIN1
# 14735  INC000023674299 2022-12-28 12:26:54  TELEPHONY LOCAL SUPPORT |SPAIN1
# 14736  INC000023674336 2022-12-28 09:18:41      NT PASSWORD RESET |EMEA, LA
# 14737  INC000023678629 2022-12-29 12:23:39    CI-CAT ADMINISTRATION |SPAIN1
#
#       Site Group Site             Incident Type  \
# 0             ES  Md1      User Service Request
# 1             ES   Md      User Service Request
# 2             ES  Md1      User Service Request
# 3             ES  Md1      User Service Request
# 4             ES   Md      User Service Request
# ...          ...  ...                       ...
# 14733         ES   Aj      User Service Request
# 14734         ES   Md  User Service Restoration
# 14735         ES   Md  User Service Restoration
# 14736         ES  Md1      User Service Request
# 14737         ES  Md1      User Service Request
#
#                         Ticket Summary         Submitter Group  \
# 0                   Usuarios expirados  ITSD - IT Service Desk
# 1               Password NT - Reset_ES  ITSD - IT Service Desk
# 2      Ampliación de validez de cuenta  ITSD - IT Service Desk
# 3              Cuenta windows expirada  ITSD - IT Service Desk
# 4               Password NT - Reset_ES  ITSD - IT Service Desk
# ...                                ...                     ...
# 14733  Mailbox - ITSP Request 19405191  ITSD - IT Service Desk
# 14734              wmedtra not working               ITSD - ES
# 14735                     Mobile phone  ITSD - IT Service Desk
# 14736                   Reset password                  Spain1
# 14737        Ampliacion cuenta windows               ITSD - ES
#
#       Last Assigned Organization Last Assigned Group        Entry Channel  \
# 0        Regional Services World        Iberia4 -Md-    CI-Hotline / ITSD
# 1        Regional Services World        Iberia4 -Md-    CI-Hotline / ITSD
# 2        Regional Services World        Iberia4 -Md-    CI-Hotline / ITSD
# 3        Regional Services World        Iberia4 -Md-    CI-Hotline / ITSD
# 4        Regional Services World        Iberia4 -Md-    CI-Hotline / ITSD
# ...                          ...                 ...                  ...
# 14733     Regional Services EMEA              Spain1    IT Service Portal
# 14734     Regional Services EMEA              Spain1    CI-Hotline / ITSD
# 14735     Regional Services EMEA              Spain1    CI-Hotline / ITSD
# 14736     Regional Services EMEA              Spain1  IT Personal Support
# 14737     Regional Services EMEA              Spain1    CI-Hotline / ITSD
#
#       Last Resolution Date           Template Name User Company  \
# 0      2020-01-02 10:36:24                     NaN           AE
# 1      2020-01-02 07:11:50  Password NT - Reset_ES         RBIB
# 2      2020-01-02 07:08:31                     NaN           AE
# 3      2020-01-03 11:00:32                     NaN           AE
# 4      2020-01-02 08:46:09  Password NT - Reset_ES           AA
# ...                    ...                     ...          ...
# 14733  2023-01-03 12:12:35                     NaN           PS
# 14734  2022-12-28 14:58:20                     NaN            C
# 14735  2022-12-28 12:57:20                     NaN           GS
# 14736  2022-12-28 09:18:41  CD/CW_only_ITS_Request           AE
# 14737  2022-12-29 12:37:23                     NaN           AE
#
#       Resolver Organization  Requisition ID Reported Source  \
# 0       IT Personal Support             NaN           Phone
# 1       IT Personal Support             NaN           Phone
# 2       IT Personal Support             NaN           Phone
# 3       IT Personal Support             NaN           Phone
# 4       IT Personal Support             NaN           Phone
# ...                     ...             ...             ...
# 14733   IT Personal Support      19405191.0    Self Service
# 14734   IT Personal Support             NaN           Phone
# 14735   IT Personal Support             NaN           Phone
# 14736   IT Personal Support             NaN         Walk In
# 14737   IT Personal Support             NaN           Phone
#
#        Last Resolution Time                               CI  Status Priority
# 0                  4.956944                              NaN  Closed   Medium
# 1                  0.514444                              NaN  Closed   Medium
# 2                  0.260278                              NaN  Closed   Medium
# 3                 27.522500                              NaN  Closed      Low
# 4                  0.860000                              NaN  Closed   Medium
# ...                     ...                              ...     ...      ...
# 14733            164.219167                              NaN  Closed      Low
# 14734             23.933889         SOFTWARE NO SCCM |SPAIN1  Closed      Low
# 14735              0.578333  TELEPHONY LOCAL SUPPORT |SPAIN1  Closed      Low
# 14736              0.020556      NT PASSWORD RESET |EMEA, LA  Closed      Low
# 14737              0.258333                              NaN  Closed      Low
#
# [14738 rows x 21 columns]

# %%
celonis_df = celonis_df.drop(['Template Name', 'Requisition ID', 'CI'], axis=1)
celonis_df.dropna(inplace=True)
celonis_df = celonis_df.drop(['Submit Date', 'Last Resolution Date', 'Ticket Summary'], axis=1)

# %%
smt_df = smt_df.drop(['Original Incident Number', 'Requisition ID', 'CI+', 'Product Name', 
                      'Resolution Product Name', 'Primary Center Code'], axis=1)
smt_df.dropna(inplace=True)
smt_df = smt_df.drop(['Created Date (UTC+0)', 'Summary', 'Last Modified Date (UTC+0)', 
                      'First Resolved Date (UTC+0)', 'Last Resolved Date (UTC+0)', 'Notes', 'Resolution'], axis=1)

# %%
smt_df = smt_df.drop(['Site Group', 'Site', 'Reported Source', 'Status'], axis=1)

# %%
combined_df = pd.merge(celonis_df, smt_df, how='inner', left_on='Incident Number', right_on='Incident ID')
combined_df.drop(['Service Name', 'Incident ID','In Progess Time (hhh:mi)\n', 'Actual Duration/Open Time (hhh:mi)', 'Customer Department', 'Desk Location', 
                  'Down Time of CI-Unavailability (hhh:mi)', 'Service+', 'Target Date'], axis=1, inplace=True)

# %%
combined_df.shape
# Out:
# (11687, 38)

# %%
columns_list = combined_df.columns
columns_list = [elem for elem in columns_list if elem not in ['Incident Number', 'Last Resolution Time']] 
combined_df_one_hot = pd.get_dummies(combined_df, columns=columns_list)
combined_df_one_hot.shape
# Out:
# (11687, 324)

# %% [markdown]
# Dividimos el conjunto de datos en entrenamiento y prueba.

# %%
X = combined_df_one_hot.drop(['Incident Number', 'Last Resolution Time'], axis=1).values
y = combined_df_one_hot['Last Resolution Time'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# %% [markdown]
# Obtenemos los 10 mayores valores de Last Resolution Time.

# %%
top10_df = pd.DataFrame({'Last Resolution Time': y_train}).nlargest(10, 'Last Resolution Time').reset_index(drop=True)
top10_df.index += 1
top10_df
# Out:
#     Last Resolution Time
# 1            4488.650000
# 2            4488.626111
# 3            3950.865278
# 4            3549.974167
# 5            3342.063889
# 6            2740.438889
# 7            2543.210278
# 8            2328.255833
# 9            2328.212778
# 10           2034.331667

# %% [markdown]
# Eliminamos el 2% superior de los outliers para Last Resolution Time.

# %%
umbral_top_percent = np.percentile(y_train, 98)
to_delete = np.where(y_train >= umbral_top_percent)
X_train = np.delete(X_train, to_delete, axis=0)
y_train = np.delete(y_train, to_delete)

# %% [markdown]
# Volvemos a obtener los 10 mayores valores de Last Resolution Time.

# %%
top10_df2 = pd.DataFrame({'Last Resolution Time': y_train}).nlargest(10, 'Last Resolution Time').reset_index(drop=True)
top10_df2.index += 1
top10_df2
# Out:
#     Last Resolution Time
# 1             363.895556
# 2             363.525278
# 3             362.711944
# 4             361.865556
# 5             360.643611
# 6             360.131667
# 7             359.998611
# 8             359.327222
# 9             358.983333
# 10            358.760278

# %% [markdown]
# Observamos como se han reducido considerablemente al eliminar los outliers. Obtenemos una tabla para comparar los 10 mayores valores de Last Resolution Time antes y después de eliminar outliers.

# %%
to10_comb_df = pd.concat([top10_df, top10_df2], axis=1)
to10_comb_df.columns = ['Con Outliers', 'Sin Outliers']
multi_index_cols = pd.MultiIndex.from_product([['Last Resolution Time'], ['Con Outliers', 'Sin Outliers']])
to10_comb_df.columns = multi_index_cols
to10_comb_df
# Out:
#    Last Resolution Time
#            Con Outliers Sin Outliers
# 1           4488.650000   363.895556
# 2           4488.626111   363.525278
# 3           3950.865278   362.711944
# 4           3549.974167   361.865556
# 5           3342.063889   360.643611
# 6           2740.438889   360.131667
# 7           2543.210278   359.998611
# 8           2328.255833   359.327222
# 9           2328.212778   358.983333
# 10          2034.331667   358.760278

# %% [markdown]
# Creación, entrenamiento y evaluación del modelo de GradientBoosting

# %%
gbr = GradientBoostingRegressor(random_state=RANDOM_STATE)

gbr.fit(X_train, y_train)

predictions = gbr.predict(X_test)

mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
print("Error cuadrático medio (MSE) en el conjunto de prueba: {:.4f}".format(mse))
print("Raíz del error cuadrático medio (RMSE) en el conjunto de prueba: {:.4f}".format(sqrt(mse)))
print("Error medio absoluto (MAE) en el conjunto de prueba: {:.4f}".format(mae))
# Out:
# Error cuadrático medio (MSE) en el conjunto de prueba: 14143.3241
# Raíz del error cuadrático medio (RMSE) en el conjunto de prueba: 118.9257
# Error medio absoluto (MAE) en el conjunto de prueba: 35.8753

# %% [markdown]
# Creación, entrenamiento y evaluación del modelo de Stochastic Gradient Descent

# %%
sgd = SGDRegressor(random_state=RANDOM_STATE)

sgd.fit(X_train, y_train)

sgd_predictions = sgd.predict(X_test)

mse = mean_squared_error(y_test, sgd_predictions)
mae = mean_absolute_error(y_test, sgd_predictions)
print("Error cuadrático medio (MSE) en el conjunto de prueba: {:.4f}".format(mse))
print("Raíz del error cuadrático medio (RMSE) en el conjunto de prueba: {:.4f}".format(sqrt(mse)))
print("Error medio absoluto (MAE) en el conjunto de prueba: {:.4f}".format(mae))
# Out:
# Error cuadrático medio (MSE) en el conjunto de prueba: 14213.8252
# Raíz del error cuadrático medio (RMSE) en el conjunto de prueba: 119.2217
# Error medio absoluto (MAE) en el conjunto de prueba: 40.3002

# %% [markdown]
# Creamos los dataframes para los explainers

# %%
X_test_df = pd.DataFrame(X_test, columns=combined_df_one_hot.drop(['Incident Number', 'Last Resolution Time'], axis=1).columns)
y_test_df = pd.DataFrame(y_test, columns=['Last Resolution Time'])

# %% [markdown]
# Creamos los cuadros de mando de explainer dashboard para analizar los modelos y obtener conclusiones

# %%
explainer = RegressionExplainer(gbr, X_test_df, y_test_df)

ExplainerDashboard(explainer).run(port = 8057)
# Out:
# Generating self.shap_explainer = shap.TreeExplainer(model)
# Building ExplainerDashboard..
# WARNING: the number of idxs (=2338) > max_idxs_in_dropdown(=1000). However with your installed version of dash(2.13.0) dropdown search may not work smoothly. You can downgrade to `pip install dash==2.6.2` which should work better for now...
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Warning: calculating shap interaction values can be slow! Pass shap_interaction=False to remove interactions tab.
# Generating layout...
# Calculating shap values...
# Calculating predictions...
# Calculating residuals...
# Calculating absolute residuals...
# Warning: mean-absolute-percentage-error is very large (144.18840542587176), you can hide it from the metrics by passing parameter show_metrics...
# Calculating shap interaction values...
# Reminder: TreeShap computational complexity is O(TLD^2), where T is the number of trees, L is the maximum number of leaves in any tree and D the maximal depth of any tree. So reducing these will speed up the calculation.

# %%
explainer = RegressionExplainer(sgd, X_test_df, y_test_df)

ExplainerDashboard(explainer).run(port = 8058)
